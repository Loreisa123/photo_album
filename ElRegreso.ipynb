# %% [markdown]
# #Base de Datos dos "el regreso de Ric"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
OCDE=pd.read_csv('BLI.csv')

# %%
OCDE.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value Flag Codes Flags
# ...

# %%
OCDE['Indicator'].unique()
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Feeling safe walking alone at night',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net financial wealth', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Voter turnout', 'Life expectancy',
#        'Self-reported health', 'Life satisfaction', 'Homicide rate',
#        'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
#Cuantos indicadores
len(OCDE['Indicator'].unique())
# Out:
# 24

# %%
#Cuantos paises
len(OCDE['Country'].unique())
# Out:
# 39

# %%
OCDE['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Brazil', 'Chile',
#        'Estonia', 'Israel', 'Latvia', 'Russia', 'Slovenia',
#        'South Africa', 'OECD - Total'], dtype=object)

# %%
OCDE2=OCDE.drop(['MEASURE','Flags','PowerCode Code','Reference Period Code','Flag Codes'],axis=1)

# %%
pd.DataFrame(OCDE2)
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %%
OCDE2=OCDE2.set_index('Indicator')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Indicator'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-fb58aaa4a9cb> in <module>()
# ...

# %%
OCDE2.head()
# Out:
#                          LOCATION         Country INDICATOR Measure  \
# Indicator
# Labour market insecurity      AUS       Australia   JE_LMIS   Value
# Labour market insecurity      AUT         Austria   JE_LMIS   Value
# Labour market insecurity      BEL         Belgium   JE_LMIS   Value
# Labour market insecurity      CAN          Canada   JE_LMIS   Value
# Labour market insecurity      CZE  Czech Republic   JE_LMIS   Value
#
#                          INEQUALITY Inequality Unit Code        Unit  \
# Indicator
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
#
#                          PowerCode  Reference Period  Value
# Indicator
# ...

# %%
#Long-term unemployment rate vs Employment rate

C_fut1=OCDE2.loc['Household net financial wealth']
C_fut1[["Unit","Value"]]
# Out:
#                                      Unit     Value
# Indicator
# Household net financial wealth  US Dollar   57462.0
# Household net financial wealth  US Dollar   59574.0
# Household net financial wealth  US Dollar  104084.0
# Household net financial wealth  US Dollar   85758.0
# Household net financial wealth  US Dollar   24258.0
# Household net financial wealth  US Dollar   73543.0
# Household net financial wealth  US Dollar   27972.0
# Household net financial wealth  US Dollar   59479.0
# Household net financial wealth  US Dollar   57358.0
# Household net financial wealth  US Dollar   18117.0
# Household net financial wealth  US Dollar   23289.0
# Household net financial wealth  US Dollar   64398.0
# Household net financial wealth  US Dollar   43493.0
# Household net financial wealth  US Dollar   64019.0
# Household net financial wealth  US Dollar   97595.0
# Household net financial wealth  US Dollar   33495.0
# Household net financial wealth  US Dollar   74141.0
# ...

# %%
C_fut=OCDE2.loc['Personal earnings']
C_fut[["Unit","Value"]]
# Out:
#                         Unit    Value
# Indicator
# Personal earnings  US Dollar  52063.0
# Personal earnings  US Dollar  48295.0
# Personal earnings  US Dollar  49587.0
# Personal earnings  US Dollar  48403.0
# Personal earnings  US Dollar  23722.0
# Personal earnings  US Dollar  52580.0
# Personal earnings  US Dollar  42127.0
# Personal earnings  US Dollar  42992.0
# Personal earnings  US Dollar  46389.0
# Personal earnings  US Dollar  25124.0
# Personal earnings  US Dollar  21711.0
# Personal earnings  US Dollar  55984.0
# Personal earnings  US Dollar  51681.0
# Personal earnings  US Dollar  35397.0
# Personal earnings  US Dollar  39113.0
# Personal earnings  US Dollar  32399.0
# Personal earnings  US Dollar  62636.0
# Personal earnings  US Dollar  15311.0
# Personal earnings  US Dollar  52833.0
# Personal earnings  US Dollar  39397.0
# Personal earnings  US Dollar  53643.0
# Personal earnings  US Dollar  25921.0
# Personal earnings  US Dollar  24529.0
# ...

# %%
plt.scatter(C_fut['Value'],C_fut1['Value'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-b9e47a58042f> in <module>()
# ----> 1 plt.scatter(C_fut['Value'],C_fut1['Value'])
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3473                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3474                          linewidths=linewidths, verts=verts,
# -> 3475                          edgecolors=edgecolors, data=data, **kwargs)
#    3476     finally:
#    3477         ax._hold = washold
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# ...

# %%
C_fut
# Out:
#                   LOCATION          Country INDICATOR Measure INEQUALITY  \
# Indicator
# Personal earnings      AUS        Australia  JE_PEARN   Value        TOT
# Personal earnings      AUT          Austria  JE_PEARN   Value        TOT
# Personal earnings      BEL          Belgium  JE_PEARN   Value        TOT
# Personal earnings      CAN           Canada  JE_PEARN   Value        TOT
# Personal earnings      CZE   Czech Republic  JE_PEARN   Value        TOT
# Personal earnings      DNK          Denmark  JE_PEARN   Value        TOT
# Personal earnings      FIN          Finland  JE_PEARN   Value        TOT
# Personal earnings      FRA           France  JE_PEARN   Value        TOT
# Personal earnings      DEU          Germany  JE_PEARN   Value        TOT
# Personal earnings      GRC           Greece  JE_PEARN   Value        TOT
# Personal earnings      HUN          Hungary  JE_PEARN   Value        TOT
# Personal earnings      ISL          Iceland  JE_PEARN   Value        TOT
# ...

# %%
C_fut3=OCDE2.loc['Labour market insecurity']
C_fut3[["Unit","Value"]]
# Out:
#                                 Unit  Value
# Indicator
# Labour market insecurity  Percentage    4.3
# Labour market insecurity  Percentage    2.7
# Labour market insecurity  Percentage    4.8
# Labour market insecurity  Percentage    3.9
# Labour market insecurity  Percentage    1.8
# Labour market insecurity  Percentage    2.3
# Labour market insecurity  Percentage    2.7
# Labour market insecurity  Percentage    5.0
# Labour market insecurity  Percentage    2.0
# Labour market insecurity  Percentage   17.4
# Labour market insecurity  Percentage    4.8
# Labour market insecurity  Percentage    2.6
# Labour market insecurity  Percentage    2.1
# Labour market insecurity  Percentage    8.1
# Labour market insecurity  Percentage    1.5
# Labour market insecurity  Percentage    2.4
# Labour market insecurity  Percentage    3.2
# Labour market insecurity  Percentage    4.6
# Labour market insecurity  Percentage    2.1
# Labour market insecurity  Percentage    4.9
# ...

# %%
C_fut4=OCDE2.loc['Time devoted to leisure and personal care']
C_fut4[["Unit","Value"]]
# Out:
#                                             Unit  Value
# Indicator
# Time devoted to leisure and personal care  Hours  14.35
# Time devoted to leisure and personal care  Hours  14.55
# Time devoted to leisure and personal care  Hours  15.77
# Time devoted to leisure and personal care  Hours  14.41
# Time devoted to leisure and personal care  Hours  15.06
# Time devoted to leisure and personal care  Hours  15.87
# Time devoted to leisure and personal care  Hours  15.17
# Time devoted to leisure and personal care  Hours  16.36
# Time devoted to leisure and personal care  Hours  15.55
# Time devoted to leisure and personal care  Hours  14.67
# Time devoted to leisure and personal care  Hours  15.06
# Time devoted to leisure and personal care  Hours  14.15
# Time devoted to leisure and personal care  Hours  15.28
# Time devoted to leisure and personal care  Hours  14.89
# Time devoted to leisure and personal care  Hours  14.85
# Time devoted to leisure and personal care  Hours  14.70
# ...
